# %% [markdown]
# # Vehicle Classification
#
# ## Evaluate your model

# %%
import os

from sklearn.metrics import accuracy_score, classification_report

from utils import utils
from models import resnet_50

# %% [markdown]
# ## Experiment settings
#
# Set here the two variables in the following way:
#
# - **CONFIG_YML:** assign the path to the config.yml file used for the experiment you want to evaluate
# - **WEIGHTS:** assign the path to the model weights (.h5 file) you want to evaluate

# %%
# Modify this
CONFIG_YML = "../experiments/3_dr_reduce_lr_more.yml"
WEIGHTS = "../experiments/3_dr_reduce_lr_more/model.08-3.1776.h5"

# %%
# (!) Don't touch this cell, will load the config file specified before
config = utils.load_config(CONFIG_YML)
config
# Out:
# {'seed': 18,
#  'data': {'directory': '/home/app/src/data/car_ims_v1/train',
#   'labels': 'inferred',
#   'label_mode': 'categorical',
#   'validation_split': 0.2,
#   'image_size': [224, 224],
#   'batch_size': 32},
#  'model': {'weights': 'experiments/3_dr_reduce_lr/model.23-3.1853.h5',
#   'input_shape': [224, 224, 3],
#   'classes': 196,
#   'dropout_rate': 0.4,
#   'data_aug_layer': {'random_flip': {'mode': 'horizontal_and_vertical'},
#    'random_rotation': {'factor': 0.2},
#    'random_zoom': {'height_factor': 0.2, 'width_factor': 0.2}}},
#  'compile': {'optimizer': {'adam': {'learning_rate': 5e-05}},
#   'loss': 'categorical_crossentropy',
#   'metrics': ['accuracy']},
#  'fit': {'epochs': 30,
#   'callbacks': {'model_checkpoint': {'filepath': '/home/app/src/experiments/3_dr_reduce_lr_more/model.{epoch:02d}-{val_loss:.4f}.h5',
#     'save_best_only': True},
#    'tensor_board': {'log_dir': '/home/app/src/experiments/3_dr_reduce_lr_more/logs'}}}}

# %%
# (!) Don't touch this cell, will use the config file to infer the class names
#     and also to load the corresponding testing dataset.
#     If you get an error, you must review your data/code.

MODEL_CLASSES = utils.get_class_names(config)

if len(MODEL_CLASSES) != config['model']['classes']:
    raise ValueError(
        "Number of classes doesn't match between your model "
        "and your data!"
    )

_dirname, _ = os.path.split(config['data']['directory'])
TEST_FOLDER = os.path.join(_dirname, 'test')

if not os.path.exists(TEST_FOLDER):
    raise ValueError("'test' folder not found!")
    
if len(os.listdir(TEST_FOLDER)) != config['model']['classes']:
    raise ValueError(
        "Number of classes doesn't match between your model "
        "and your testing dataset!"
    )
    
if set(os.listdir(TEST_FOLDER)) != set(MODEL_CLASSES):
    raise ValueError(
        "The name of the subfolders inside your test set "
        "doesn't match with the model classes!"
    )

# %% [markdown]
# ## Load your model
#
# Use `resnet_50.create_model()` and remember to properly setup the model weights!
#
# Assign the model to the variable `cnn_model`.

# %%
# Complete this
# TODO
cnn_model = resnet_50.create_model(weights=WEIGHTS)

# It should print your model correctly
print(cnn_model.summary())
# Out:
# 2022-11-21 17:24:30.515444: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-11-21 17:24:30.551055: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-11-21 17:24:30.551525: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-11-21 17:24:30.552463: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-21 17:24:30.563783: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-11-21 17:24:30.564451: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-11-21 17:24:30.564939: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-11-21 17:24:32.961324: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-11-21 17:24:32.961817: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-11-21 17:24:32.961836: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1609] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2022-11-21 17:24:32.962254: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-11-21 17:24:32.962316: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6264 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1070 with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 6.1
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  tf.__operators__.getitem (S  (None, 224, 224, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 224, 224, 3)      0
#
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 196)               401604
#
# =================================================================
# Total params: 23,989,316
# Trainable params: 401,604
# Non-trainable params: 23,587,712
# _________________________________________________________________
# None

# %% [markdown]
# ## Get predictions from testing dataset

# %%
# (!) Don't touch this cell, will use the loaded model and
#     the function utils.predict_from_folder() to get 
#     model predictions and the corresponding true labels
#     so we can measure the accuracy

predictions, labels = utils.predict_from_folder(
    folder=TEST_FOLDER, 
    model=cnn_model, 
    input_size=config["data"]["image_size"], 
    class_names=MODEL_CLASSES,
)

if len(predictions) != len(labels):
    raise ValueError(
        "The lenght of predictions and labels lists doesn't match!"
    )

if not isinstance(predictions[0], str):
    raise ValueError(
        "Model predictions should be represented as string. E.g: 'Acura RL Sedan 2012'"
    )

if not isinstance(labels[0], str):
    raise ValueError(
        "Ground true labels should be represented as string. E.g: 'Acura RL Sedan 2012'"
    )
# Out:
# 2022-11-21 17:25:08.401705: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8200
# 2022-11-21 17:25:12.190792: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-11-21 17:25:12.194203: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-11-21 17:25:12.194309: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2022-11-21 17:25:12.196562: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-11-21 17:25:12.196874: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.

# %%
# (!) Don't touch this cell

print(classification_report(y_true=labels, y_pred=predictions))
# Out:
#                                                         precision    recall  f1-score   support
#
#                             AM General Hummer SUV 2000       0.82      0.64      0.72        44
#                              Acura Integra Type R 2001       0.35      0.41      0.38        44
#                                    Acura RL Sedan 2012       0.36      0.16      0.22        32
#                                    Acura TL Sedan 2012       0.37      0.33      0.35        43
#                                   Acura TL Type-S 2008       0.22      0.19      0.20        42
#                                   Acura TSX Sedan 2012       0.19      0.07      0.11        40
#                               Acura ZDX Hatchback 2012       0.18      0.18      0.18        39
#               Aston Martin V8 Vantage Convertible 2012       0.32      0.27      0.29        45
#                     Aston Martin V8 Vantage Coupe 2012       0.25      0.02      0.04        41
#                   Aston Martin Virage Convertible 2012       0.26      0.27      0.26        33
#                         Aston Martin Virage Coupe 2012       0.43      0.68      0.53        38
#                                    Audi 100 Sedan 1994       0.50      0.25      0.33        40
#                                    Audi 100 Wagon 1994       0.46      0.31      0.37        42
#                                     Audi A5 Coupe 2012       0.36      0.10      0.15        41
#                                     Audi R8 Coupe 2012       0.50      0.05      0.09        43
#                             Audi RS 4 Convertible 2008       0.70      0.19      0.30        36
#                                     Audi S4 Sedan 2007       0.25      0.07      0.11        45
#                                     Audi S4 Sedan 2012       0.10      0.23      0.14        39
#                               Audi S5 Convertible 2012       0.37      0.24      0.29        42
#                                     Audi S5 Coupe 2012       0.00      0.00      0.00        42
#                                     Audi S6 Sedan 2011       0.26      0.11      0.15        46
#                                 Audi TT Hatchback 2011       0.39      0.23      0.29        40
#                                  Audi TT RS Coupe 2012       0.14      0.13      0.14        39
#                                    Audi TTS Coupe 2012       0.23      0.12      0.16        42
#                                     Audi V8 Sedan 1994       0.29      0.12      0.17        43
#                          BMW 1 Series Convertible 2012       0.73      0.23      0.35        35
#                                BMW 1 Series Coupe 2012       0.64      0.22      0.33        41
#                                BMW 3 Series Sedan 2012       0.25      0.10      0.14        42
#                                BMW 3 Series Wagon 2012       0.43      0.07      0.12        41
#                          BMW 6 Series Convertible 2007       0.25      0.11      0.16        44
#                       Mercedes-Benz C-Class Sedan 2012       0.23      0.18      0.20        45
#                       Mercedes-Benz E-Class Sedan 2012       0.05      0.19      0.08        43
#                       Mercedes-Benz S-Class Sedan 2012       0.27      0.25      0.26        44
#                      Mercedes-Benz SL-Class Coupe 2009       0.23      0.08      0.12        36
#                        Mercedes-Benz Sprinter Van 2012       0.54      0.78      0.64        41
#                           Mitsubishi Lancer Sedan 2012       0.06      0.34      0.10        47
#                                Nissan 240SX Coupe 1998       0.35      0.17      0.23        46
#                             Nissan Juke Hatchback 2012       0.17      0.41      0.24        44
#                             Nissan Leaf Hatchback 2012       0.34      0.62      0.44        42
#                           Nissan NV Passenger Van 2012       0.40      0.71      0.51        38
#                               Plymouth Neon Coupe 1999       0.55      0.39      0.45        44
#                            Porsche Panamera Sedan 2012       0.11      0.23      0.15        43
#                         Ram C-V Cargo Van Minivan 2012       0.71      0.29      0.41        41
#                           Rolls-Royce Ghost Sedan 2012       0.15      0.32      0.20        38
#    Rolls-Royce Phantom Drophead Coupe Convertible 2012       0.64      0.23      0.34        30
#                         Rolls-Royce Phantom Sedan 2012       0.52      0.36      0.43        44
#                                Scion xD Hatchback 2012       0.31      0.29      0.30        41
#                             Spyker C8 Convertible 2009       0.62      0.36      0.45        45
#                                   Spyker C8 Coupe 2009       0.52      0.29      0.37        42
#                                Suzuki Aerio Sedan 2007       0.46      0.29      0.35        38
#                              Suzuki Kizashi Sedan 2012       0.20      0.11      0.14        46
#                              Suzuki SX4 Hatchback 2012       0.08      0.45      0.14        42
#                                  Suzuki SX4 Sedan 2012       0.08      0.07      0.08        40
#                               Tesla Model S Sedan 2012       0.54      0.18      0.27        38
#                                Toyota 4Runner SUV 2012       0.55      0.15      0.24        40
#                                Toyota Camry Sedan 2012       0.17      0.33      0.22        43
#                              Toyota Corolla Sedan 2012       0.47      0.16      0.24        43
#                                Toyota Sequoia SUV 2012       0.83      0.13      0.23        38
#                       Volkswagen Beetle Hatchback 2012       0.25      0.69      0.36        42
#                         Volkswagen Golf Hatchback 1991       0.32      0.52      0.40        46
#                         Volkswagen Golf Hatchback 2012       0.33      0.09      0.15        43
#                                   Volvo 240 Sedan 1993       0.23      0.87      0.36        45
#                               Volvo C30 Hatchback 2012       0.39      0.37      0.38        41
#                                    Volvo XC90 SUV 2007       0.31      0.19      0.23        43
#                          smart fortwo Convertible 2012       0.82      0.45      0.58        40
#
#                                               accuracy                           0.27      8041
#                                              macro avg       0.39      0.27      0.28      8041
#                                           weighted avg       0.38      0.27      0.27      8041

# %%
# (!) Don't touch this cell

acc = accuracy_score(y_true=labels, y_pred=predictions)

print(f"Your model accuracy is {acc:.4f}!")

if acc < .3:
    raise ValueError("Your model accuracy is too low :(\nYou can do it better! :)")
# Out:
# Your model accuracy is 0.2727!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [8], line 8
#       5 print(f"Your model accuracy is {acc:.4f}!")
#       7 if acc < .3:
# ----> 8     raise ValueError("Your model accuracy is too low :(\nYou can do it better! :)")
#
# ValueError: Your model accuracy is too low :(
# You can do it better! :)
